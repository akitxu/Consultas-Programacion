# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# En la carpeta Ficheros_R4.csv, se encuentran ficheros descargados de un banco, cuya caracteística principal es que utiliza la coma como separador decimal y \t como separador.
#
# Importo cualquiera de estos ficheros individualmente y los grafico, con normalidad, como podemos ver a continuación.

# %%
import pandas as pd

df = pd.read_csv("./Ficheros_R4_csv/Acatis.csv",
                     decimal  =",",  na_values = ["nan"], sep='\t')
    
df.plot(figsize=(8, 6), color='green', title = 'Line Plot', fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Line Plot'}>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2854 entries, 0 to 2853
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2853 non-null   object
#  1   Close   2852 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 44.7+ KB

# %%
# Importar ficheros csv descargados de Renta 4
import glob
import pandas as pd

"""Importa los datos de los ficheros csv de una dirección determinada"""
filenames = glob.glob(path + "*.csv") 
dfs = []
nombres = []
for filename in filenames: 
    nombre = filename[len(path):-4] 
    nombres.append(nombre)        
    
    dfs.append(pd.read_csv(filename, decimal  =",",  na_values = ["nan"], sep='\t'))     
    
dfs = iter(dfs)
df_R4 = next(dfs)
for df_ in dfs:
    df_R4 = df_R4.merge(df_, on='Date')

df_R4['Date'] = pd.to_datetime(df_R4['Date'], errors='coerce')

df_R4.set_index("Date",inplace=True) 

df_R4.columns = nombres

df = df_R4[["Acatis"]]

df.plot(figsize=(8, 6), color='green', title = 'Line Plot', fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Line Plot'}, xlabel='Date'>

# %%
# Importar ficheros csv descargados de Renta 4
import glob 
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
from datetime import date

# Dirección para obtener los ficheros 
path = "/media/enri/Mi_Proyecto/Py_Proyecto_2020/Py_Paso_Peregrino/Ficheros_Yahoo_csv/"

"""Importa los datos de los ficheros csv de una dirección determinada"""
filenames = glob.glob(path + "*.csv") 
dfs = []
nombres = []
for filename in filenames: 
    nombre = filename[len(path):-4] 
    nombres.append(nombre)    
    #dfs.append(pd.read_csv(filename, index_col = "Date", names = nombres))
    dfs.append( pd.read_csv(filename ,index_col = "Date", parse_dates = ["Date"], 
                            na_values = ["nan"]))
dfs = iter(dfs)
df_yahoo = next(dfs)
for df_ in dfs:
    df_yahoo = df_yahoo.merge(df_, on='Date')
    
#df_yahoo = df_yahoo.set_index("Date")
    
df_yahoo.columns = nombres
#df_yahoo.dropna(inplace = True)

df_yahoo.reset_index(inplace = True)

df_yahoo['Date'] = pd.to_datetime(df_yahoo['Date'], errors='coerce')
#df_yahoo['Date'] = df_yahoo['Date'].dt.strftime('%d/%m/%Y')

df_yahoo = df_yahoo.set_index("Date")

df_yahoo[:3]
# Out:
#                  dowjons     Endesa  Eurostoxx50  iberdrola        ibex35  \
# Date
# 2007-11-14  13231.009766  36.840000  4338.279785      11.53  15808.900391
# 2007-11-15  13110.049805  36.849998  4301.439941      11.56  15725.799805
# 2007-11-16  13176.790039  36.849998  4282.399902      11.65  15769.000000
#
#                  nasdaq     nikkei225   renta4        sp500        SPY  \
# Date
# 2007-11-14  2644.320068  15499.559570  7.85872  1470.579956  36.840000
# 2007-11-15  2618.510010  15396.299805  7.46578  1451.150024  36.849998
# 2007-11-16  2637.239990  15154.610352  7.49319  1458.739990  36.849998
#
#             telefonica        XOM
# Date
# 2007-11-14   22.531900  86.309998
# 2007-11-15   22.353901  84.489998
# 2007-11-16   22.601101  85.099998

# %%
# Seleccionar un valor y un indicador de referencia.
lista_valores = df_R4.columns
lista_indices = df_yahoo.columns
#lista_MSCI = df_MSCI.columns

def selec_activo_financiero (lista):
    for counter, value in enumerate(lista):
        print(counter, value)      
    print ("\t20 - Salir")
    # solicitamos una opción de valor al usuario
    activo = int (input("\nSeleccione un valor  \n") )
    nombre = lista[activo]

    if activo == 20:
        exit()
        
    if activo >= 20 :
        input("\nNo has pulsado ninguna opción correcta...\npulsa una tecla para continuar\n")

    return nombre

nom_val =  selec_activo_financiero (lista_valores)
nom_ind =  selec_activo_financiero (lista_indices)

df_valor = df_R4[[nom_val]]
df_indice = df_yahoo[[nom_ind]]

val_ind = pd.merge(df_valor, df_indice, left_index=True, right_index=True)
# Out:
# 0 Acatis
# 1 DedaloPP
# 2 NexusPP
# 3 TrueValue
# 4 ValorRelativo
# 	20 - Salir
#
# Seleccione un valor
# 0
# 0 dowjons
# 1 Endesa
# 2 Eurostoxx50
# 3 iberdrola
# 4 ibex35
# 5 nasdaq
# 6 nikkei225
# 7 renta4
# 8 sp500
# 9 SPY
# 10 telefonica
# 11 XOM
# 	20 - Salir
#
# Seleccione un valor
# 2

# %%
df_R4[[nom_val]][:3]
# Out:
#             Acatis
# Date
# 2008-12-15  100.00
# 2008-12-16   99.97
# 2008-12-17   99.96

# %%
df_R4[["Acatis"]].plot(figsize=(8, 6), color='green', title = 'Line Plot', fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Line Plot'}, xlabel='Date'>

# %%
# Dirección para obtener los ficheros 
path = "/media/enri/Mi_Proyecto/Py_Proyecto_2020/Py_Paso_Peregrino/Ficheros_Yahoo_csv/"


df = pd.read_csv("/media/enri/Mi_Proyecto/Py_Proyecto_2020/Py_Paso_Peregrino/Ficheros_R4_csv/Acatis.csv",
                     decimal  =",",  na_values = ["nan"], sep='\t')
    
df.plot(figsize=(8, 6), color='green', title = 'Line Plot', fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Line Plot'}>

# %%
df_yahoo[["iberdrola"]].plot(figsize=(8, 6), color='green', title = 'Line Plot', fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Line Plot'}, xlabel='Date'>
